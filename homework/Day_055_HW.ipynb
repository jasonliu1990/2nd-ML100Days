# %% [markdown]
# # 作業
#
# - 作業目標 : iris (dataset.load_iris()) 資料嘗試跑 kmeans (可以測試不同的群數 , init 等)

# %%
from sklearn import datasets
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# ### 載入 相關套件 並 執行 kmean 實驗 ...
#
# - 實驗測試不同的群數
# - 實驗測試不同的初始值
# - 呈現結果

# %%
""" 分群結果評價
    wcss: with-in cluster sum of square
      
"""
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, max_iter=300, n_init=10,
                   init='k-means++', random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11), wcss)
plt.title('the elbow method')
plt.xlabel('number of cluster')
plt.ylabel('wcss')
plt.show()

# %%
# Applying the k-means to the dataset -> n_clusters = 2
kmeans = KMeans(n_clusters = 2, max_iter = 300, n_init = 10, init = 'k-means++', random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# Visualizing 
fignum = 1
fig = plt.figure(fignum, figsize=(4, 3))
ax = Axes3D(fig , rect=[0, 0, 2, 2.5], elev = 48 , azim = 134)
ax.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], X[y_kmeans == 0, 2], s = 100, c = 'red', label = 'Careful')
ax.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], X[y_kmeans == 1, 2], s = 100, c = 'blue', label = 'Standard')
ax.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, 2], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of iris, cluster=%s'%i)
plt.xlabel('feature_0')
plt.ylabel('feature_1')
plt.legend()
plt.show()

# %%
# Applying the k-means to the dataset -> n_clusters = 3
kmeans = KMeans(n_clusters = 3, max_iter = 300, n_init = 10, init = 'k-means++', random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# Visualizing 
fignum = 1
fig = plt.figure(fignum, figsize=(4, 3))
ax = Axes3D(fig , rect=[0, 0, 2, 2.5], elev = 48 , azim = 134)
ax.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], X[y_kmeans == 0, 2], s = 100, c = 'red', label = 'Careful')
ax.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], X[y_kmeans == 1, 2], s = 100, c = 'blue', label = 'Standard')
ax.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], X[y_kmeans == 2, 2], s = 100, c = 'green', label = 'Target')
ax.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, 2], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of iris, cluster=%s'%i)
plt.xlabel('feature_0')
plt.ylabel('feature_1')
plt.legend()
plt.show()

# %%
# Applying the k-means to the dataset -> n_clusters = 4
kmeans = KMeans(n_clusters = 4, max_iter = 300, n_init = 10, init = 'k-means++', random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# Visualizing 
fignum = 1
fig = plt.figure(fignum, figsize=(4, 3))
ax = Axes3D(fig , rect=[0, 0, 2, 2.5], elev = 48 , azim = 134)
ax.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], X[y_kmeans == 0, 2], s = 100, c = 'red', label = 'Careful')
ax.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], X[y_kmeans == 1, 2], s = 100, c = 'blue', label = 'Standard')
ax.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], X[y_kmeans == 2, 2], s = 100, c = 'green', label = 'Target')
ax.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], X[y_kmeans == 3, 2], s = 100, c = 'cyan', label = 'Careless')
ax.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, 2], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of iris')
plt.xlabel('feature_0')
plt.ylabel('feature_1')
plt.legend()
plt.show()
